# %% [markdown]
# <a href="https://colab.research.google.com/github/mandyjannycia/1142---Advanced-Programming-Course/blob/main/4Sum2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fourSum(nums: list[int], target: int) -> list[list[int]]:
    nums.sort()
    result = set()
    n = len(nums)

    for i in range(n - 3):
        for j in range(i + 1, n - 2):
            seen = set()
            for k in range(j + 1, n):
                complement = target - nums[i] - nums[j] - nums[k]
                if complement in seen:
                    result.add((nums[i], nums[j], complement, nums[k]))
                seen.add(nums[k])

    return [list(t) for t in result]
