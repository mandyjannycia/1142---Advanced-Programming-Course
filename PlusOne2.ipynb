# %% [markdown]
# <a href="https://colab.research.google.com/github/mandyjannycia/1142---Advanced-Programming-Course/blob/main/PlusOne2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def plusOne(digits):
    num_str = ''.join(map(str, digits))
    num = int(num_str)
    num += 1
    return [int(digit) for digit in str(num)]
